# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('MegaMart_sales.csv')
df.head()
# Out:
#           Order ID                                Product Name  Discount  \
# 0  AZ-2011-1029887  Novimex Color Coded Labels, 5000 Label Set       0.0
# 1   AZ-2011-107716              Deflect-O Door Stop, Erganomic       0.0
# 2  AZ-2011-1087704               Belkin Flash Drive, Bluetooth       0.0
# 3  AZ-2011-1372644                  Panasonic Printer, Durable       0.0
# 4  AZ-2011-1362199                   Sanford Pens, Fluorescent       0.5
#
#    Sales  Profit  Quantity         Category Sub-Category
# 0     26       7         2  Office Supplies       Labels
# 1     85      15         2        Furniture  Furnishings
# 2    294     109         7       Technology  Accessories
# 3    800     168         3       Technology     Machines
# 4     25     -11         4  Office Supplies          Art

# %%
df_new = pd.read_csv('MegaMart_newsales.csv')
df_new.head()
# Out:
#           Order ID                         Product Name  Discount  Sales  \
# 0  AZ-2011-1902971  Wilson Jones Binding Machine, Clear       0.0    339
# 1  AZ-2011-1916360        Dania 3-Shelf Cabinet, Mobile       0.0    288
# 2  AZ-2011-1916555          Eldon Folders, Single Width       0.4     61
# 3  AZ-2011-1930058          Sanford Markers, Easy-Erase       0.0     71
# 4  AZ-2011-1967754         Logitech Numeric Keypad, USB       0.0     93
#
#    Profit  Quantity         Category Sub-Category
# 0     102         7  Office Supplies      Binders
# 1      20         2        Furniture    Bookcases
# 2       7         6  Office Supplies      Storage
# 3       1         3  Office Supplies          Art
# 4      40         2       Technology  Accessories

# %%
df.columns
# Out:
# Index(['Order ID', 'Product Name', 'Discount', 'Sales', 'Profit', 'Quantity',
#        'Category', 'Sub-Category'],
#       dtype='object')

# %%
df_new.columns == df.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# #### Combining two data frames
# Question 1: Some of the orders are stored in another csv file named `megamart_new sales`. Read the csv file, store it in a data frame and add it to the `megamart_sales` data frame. Find the total sales value of the category 'Office Supplies'  after combining the dataframes
#
#     a)7970
#     b)6964
#     c)7494
#     d)6076

# %%
#your code here
df = pd.concat([df, df_new], axis = 0, ignore_index = True)
df.head()

# ignore_index: 

# if True, the indexes from the source objects will be ignored 
# and a sequence of indexes from 0,1,2…n will be assigned to the result. 
# keys: a sequence to add an identifier to the result indexes.
# Out:
#           Order ID                                Product Name  Discount  \
# 0  AZ-2011-1029887  Novimex Color Coded Labels, 5000 Label Set       0.0
# 1   AZ-2011-107716              Deflect-O Door Stop, Erganomic       0.0
# 2  AZ-2011-1087704               Belkin Flash Drive, Bluetooth       0.0
# 3  AZ-2011-1372644                  Panasonic Printer, Durable       0.0
# 4  AZ-2011-1362199                   Sanford Pens, Fluorescent       0.5
#
#    Sales  Profit  Quantity         Category Sub-Category
# 0     26       7         2  Office Supplies       Labels
# 1     85      15         2        Furniture  Furnishings
# 2    294     109         7       Technology  Accessories
# 3    800     168         3       Technology     Machines
# 4     25     -11         4  Office Supplies          Art

# %%
df_by = df.groupby(by = 'Category')
df_by

# %%
total = df_by['Sales'].sum()
total
# Out:
# Category
# Furniture          2460
# Office Supplies    7970
# Technology         8588
# Name: Sales, dtype: int64

# %%
# Ans.
total['Office Supplies']
# Out:
# 7970

# %% [markdown]
# #### Dropping duplicates
# Question 2: There are some duplicate rows in the data frame. Drop these rows and calculate the total sales value of the category Office Supplies.
#
#     a)7156
#     b)6496
#     c)6964
#     d)6023

# %% [markdown]
# Pandas Series: drop_duplicates() function
# -----------
#
#     import numpy as np
#     import pandas as pd
#     s = pd.Series(['cat', 'cow', 'cat', 'dog', 'cat', 'fox'],
#                   name='animal')
#     s.drop_duplicates(keep=False, inplace=True)
#     s
#
# Output:
#
#     1    cow
#     3    dog
#     5    fox
#     Name: animal, dtype: object
#
# <br>
# <center>
# <table class="table table-bordered">
# <tbody><tr>
# <th>Name</th>
# <th>Description</th>
# <th>Type/Default Value </th>
# <th>Required / Optional</th>
# </tr>
# <tr>
# <td>keep </td>
# <td><ul class="w3r_list"><li>‘first’ : Drop duplicates except for the first occurrence.</li>
# <li>‘last’ : Drop duplicates except for the last occurrence.</li>
# <li>False : Drop all duplicates.</li></ul></td>
# <td>{‘first’, ‘last’, False}<br>
# Default Value: ‘first’</td>
# <td>Required</td>
# </tr>
# <tr>
# <td>inplace</td>
# <td>If True, performs operation inplace and returns None.</td>
# <td>bool<br>
# Default Value: False</td>
# <td>Required</td>
# </tr>
# </tbody></table>
#
# <br>
#
# ![ss](https://www.w3resource.com/w3r_images/pandas-series-drop_duplicates-image-2.svg)
#
# </center>
#
# [Source Code](https://www.w3resource.com/pandas/series/series-drop_duplicates.php)

# %%
#your code here
df.drop_duplicates(subset = None, keep = 'first', inplace = True)
df.head()
# Out:
#           Order ID                                Product Name  Discount  \
# 0  AZ-2011-1029887  Novimex Color Coded Labels, 5000 Label Set       0.0
# 1   AZ-2011-107716              Deflect-O Door Stop, Erganomic       0.0
# 2  AZ-2011-1087704               Belkin Flash Drive, Bluetooth       0.0
# 3  AZ-2011-1372644                  Panasonic Printer, Durable       0.0
# 4  AZ-2011-1362199                   Sanford Pens, Fluorescent       0.5
#
#    Sales  Profit  Quantity         Category Sub-Category
# 0     26       7         2  Office Supplies       Labels
# 1     85      15         2        Furniture  Furnishings
# 2    294     109         7       Technology  Accessories
# 3    800     168         3       Technology     Machines
# 4     25     -11         4  Office Supplies          Art

# %%
total_new = df.groupby(by = 'Category')['Sales'].sum()
total_new
# Out:
# Category
# Furniture          2460
# Office Supplies    6964
# Technology         7494
# Name: Sales, dtype: int64

# %%
# Ans.
total_new['Office Supplies']
# Out:
# 6964

# %% [markdown]
# #### Best category-sub category
# Question 3: Find the most profitable category and sub category combination based on the net profit.
#
#
#     a)Furniture-Bookcases
#     b)Office supplies-Appliances
#     c)Office supplies-Storage
#     d)Technology-Phones

# %%
#your code here
df_grouped = df.groupby(by = ['Category', 'Sub-Category'])['Profit'].sum()
df_grouped
# Out:
# Category         Sub-Category
# Furniture        Bookcases        308
#                  Chairs           -49
#                  Furnishings       74
# Office Supplies  Appliances       229
#                  Art              275
#                  Binders          156
#                  Envelopes         35
#                  Fasteners         10
#                  Labels            30
#                  Paper             15
#                  Storage          192
#                  Supplies         103
# Technology       Accessories      215
#                  Copiers            0
#                  Machines         168
#                  Phones          1618
# Name: Profit, dtype: int64

# %%
# Ans. Technology  Phones
df_grouped[df_grouped == df_grouped.max()]
# Out:
# Category    Sub-Category
# Technology  Phones          1618
# Name: Profit, dtype: int64

# %% [markdown]
# #### Invalid order IDs
# How many invalid Order IDs are there in the data frame. Order ID is of the form AZ-2011-Y where Y represents a whole number. An Order ID is said to be valid only if Y consists of 7 digits. Find the number of `invalid order IDs` in the data frame.
#
# Note: Use duplicates dropped data frame
#
#     a)6
#     b)7
#     c)8
#     d)9

# %%
#your code here
df['Order no'] = df['Order ID'].str.split('-')
df.head()
# Out:
#           Order ID                                Product Name  Discount  \
# 0  AZ-2011-1029887  Novimex Color Coded Labels, 5000 Label Set       0.0
# 1   AZ-2011-107716              Deflect-O Door Stop, Erganomic       0.0
# 2  AZ-2011-1087704               Belkin Flash Drive, Bluetooth       0.0
# 3  AZ-2011-1372644                  Panasonic Printer, Durable       0.0
# 4  AZ-2011-1362199                   Sanford Pens, Fluorescent       0.5
#
#    Sales  Profit  Quantity         Category Sub-Category             Order no
# 0     26       7         2  Office Supplies       Labels  [AZ, 2011, 1029887]
# 1     85      15         2        Furniture  Furnishings   [AZ, 2011, 107716]
# 2    294     109         7       Technology  Accessories  [AZ, 2011, 1087704]
# 3    800     168         3       Technology     Machines  [AZ, 2011, 1372644]
# 4     25     -11         4  Office Supplies          Art  [AZ, 2011, 1362199]

# %%
df['Order no'] = df['Order no'].apply(lambda x: x[2])
df.head()
# Out:
#           Order ID                                Product Name  Discount  \
# 0  AZ-2011-1029887  Novimex Color Coded Labels, 5000 Label Set       0.0
# 1   AZ-2011-107716              Deflect-O Door Stop, Erganomic       0.0
# 2  AZ-2011-1087704               Belkin Flash Drive, Bluetooth       0.0
# 3  AZ-2011-1372644                  Panasonic Printer, Durable       0.0
# 4  AZ-2011-1362199                   Sanford Pens, Fluorescent       0.5
#
#    Sales  Profit  Quantity         Category Sub-Category Order no
# 0     26       7         2  Office Supplies       Labels  1029887
# 1     85      15         2        Furniture  Furnishings   107716
# 2    294     109         7       Technology  Accessories  1087704
# 3    800     168         3       Technology     Machines  1372644
# 4     25     -11         4  Office Supplies          Art  1362199

# %%
df['no_of_digits'] = df['Order no'].apply(lambda x: len(x))
df.head()
# Out:
#           Order ID                                Product Name  Discount  \
# 0  AZ-2011-1029887  Novimex Color Coded Labels, 5000 Label Set       0.0
# 1   AZ-2011-107716              Deflect-O Door Stop, Erganomic       0.0
# 2  AZ-2011-1087704               Belkin Flash Drive, Bluetooth       0.0
# 3  AZ-2011-1372644                  Panasonic Printer, Durable       0.0
# 4  AZ-2011-1362199                   Sanford Pens, Fluorescent       0.5
#
#    Sales  Profit  Quantity         Category Sub-Category Order no  \
# 0     26       7         2  Office Supplies       Labels  1029887
# 1     85      15         2        Furniture  Furnishings   107716
# 2    294     109         7       Technology  Accessories  1087704
# 3    800     168         3       Technology     Machines  1372644
# 4     25     -11         4  Office Supplies          Art  1362199
#
#    no_of_digits
# 0             7
# 1             6
# 2             7
# 3             7
# 4             7

# %%
count_invalid = df['no_of_digits'].value_counts()
count_invalid # only ID length of 7 is valid
# Out:
# 7    54
# 6     7
# Name: no_of_digits, dtype: int64

# %%
# Ans.
count_invalid.loc[6] # this Series has 6 as invalid ID
# Out:
# 7

# %% [markdown]
# #### Occurence of furniture in top 25 sales
# Question 5: Find the top 25 orders based on sales value and find the number of orders which belong to furniture category.
#
#     a)2
#     b)3
#     c)4
#     d)5

# %%
#your code here
df2 = df.sort_values(by = 'Sales', ascending = False)
df2
# Out:
#            Order ID                                Product Name  Discount  \
# 30  AZ-2011-1410648                Nokia Smart Phone, Full Size       0.0
# 58   AZ-2011-176674                       Hoover Microwave, Red       0.1
# 8   AZ-2011-1174243            Nokia Audio Dock, with Caller ID       0.0
# 20  AZ-2011-1322840            Motorola Headset, with Caller ID       0.0
# 3   AZ-2011-1372644                  Panasonic Printer, Durable       0.0
# ..              ...                                         ...       ...
# 44  AZ-2011-1603295                  Ibico Binder Covers, Clear       0.5
# 53  AZ-2011-1723003                      Ibico Index Tab, Clear       0.0
# 50  AZ-2011-1680940          Smead Round Labels, 5000 Label Set       0.0
# 27  AZ-2011-1366554                    Avery Index Tab, Durable       0.0
# 35  AZ-2011-1474073  Wilson Jones Hole Reinforcements, Recycled       0.0
#
#     Sales  Profit  Quantity         Category Sub-Category Order no  \
# ...

# %%
df2 = df2.iloc[ :25, :]
df2
# Out:
#            Order ID                         Product Name  Discount  Sales  \
# 30  AZ-2011-1410648         Nokia Smart Phone, Full Size       0.0   1908
# 58   AZ-2011-176674                Hoover Microwave, Red       0.1   1667
# 8   AZ-2011-1174243     Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840     Motorola Headset, with Caller ID       0.0    957
# 3   AZ-2011-1372644           Panasonic Printer, Durable       0.0    800
# 18  AZ-2011-1406494         Fellowes Lockers, Industrial       0.1    748
# 39  AZ-2011-1536006      Logitech Keyboard, Programmable       0.0    666
# 33  AZ-2011-1445262          Apple Smart Phone, Cordless       0.0    636
# 31   AZ-2011-144325        Bush Stackable Bookrack, Pine       0.0    630
# 14  AZ-2011-1260928        Eldon File Cart, Single Width       0.1    576
# 12  AZ-2011-1253407       Safco Stackable Bookrack, Pine       0.1    541
# 48  AZ-2011-1672552      Binney & Smith Sketch Pad, Blue       0.0    510
# ...

# %%
df2_cat = df2['Category']
df2_cat
# Out:
# 30         Technology
# 58    Office Supplies
# 8          Technology
# 20         Technology
# 3          Technology
# 18    Office Supplies
# 39         Technology
# 33         Technology
# 31          Furniture
# 14    Office Supplies
# 12          Furniture
# 48    Office Supplies
# 41         Technology
# 52         Technology
# 59    Office Supplies
# 17          Furniture
# 2          Technology
# 60          Furniture
# 11    Office Supplies
# 34    Office Supplies
# 6     Office Supplies
# 42    Office Supplies
# 38    Office Supplies
# 46    Office Supplies
# 43          Furniture
# Name: Category, dtype: object

# %%
df2_count = df2_cat.value_counts()
df2_count
# Out:
# Office Supplies    11
# Technology          9
# Furniture           5
# Name: Category, dtype: int64

# %%
# Ans.
df2_count['Furniture']
# Out:
# 5

# %% [markdown]
# #### And operation
# Question 6: Among the orders with sales>250 and profit>50, find the product name of the fourth highest order based on sales value.
#
# Note: Use duplicates dropped data frame
#
#     a)Motorola Headset, with Caller ID
#     b)Panasonic Printer, Durable
#     c)Hoover Microwave, Red
#     d)Fellowes Lockers, Industrial

# %%
#your code here
df3 = df.loc[(df['Sales'] > 250) & (df['Profit'] > 50)]
df3.head()
# Out:
#            Order ID                      Product Name  Discount  Sales  \
# 2   AZ-2011-1087704     Belkin Flash Drive, Bluetooth       0.0    294
# 3   AZ-2011-1372644        Panasonic Printer, Durable       0.0    800
# 8   AZ-2011-1174243  Nokia Audio Dock, with Caller ID       0.0   1334
# 12  AZ-2011-1253407    Safco Stackable Bookrack, Pine       0.1    541
# 14  AZ-2011-1260928     Eldon File Cart, Single Width       0.1    576
#
#     Profit  Quantity         Category Sub-Category Order no  no_of_digits
# 2      109         7       Technology  Accessories  1087704             7
# 3      168         3       Technology     Machines  1372644             7
# 8      200         8       Technology       Phones  1174243             7
# 12     156         4        Furniture    Bookcases  1253407             7
# 14      51         5  Office Supplies      Storage  1260928             7

# %%
len(df), len(df3)
# Out:
# (61, 16)

# %%
df3 = df3.sort_values(by = 'Sales', ascending = False)
df3.head()
# Out:
#            Order ID                      Product Name  Discount  Sales  \
# 30  AZ-2011-1410648      Nokia Smart Phone, Full Size       0.0   1908
# 58   AZ-2011-176674             Hoover Microwave, Red       0.1   1667
# 8   AZ-2011-1174243  Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840  Motorola Headset, with Caller ID       0.0    957
# 3   AZ-2011-1372644        Panasonic Printer, Durable       0.0    800
#
#     Profit  Quantity         Category Sub-Category Order no  no_of_digits
# 30     820         3       Technology       Phones  1410648             7
# 58     185         6  Office Supplies   Appliances   176674             6
# 8      200         8       Technology       Phones  1174243             7
# 20     316        12       Technology       Phones  1322840             7
# 3      168         3       Technology     Machines  1372644             7

# %%
# Ans. product name of the fourth highest order has index 3
df3['Product Name'].iloc[3]
# Out:
# 'Motorola Headset, with Caller ID'

# %% [markdown]
# #### Column manipulation
# Question 7: Remove the orders with negative profit by dropping the corresponding rows with `negative Profit or no Profit`. Now, among the entries with non-negative profit, find the product that makes the `lowest profit per Quantity` in the `Technology category`.
#
# Note: Use duplicates dropped data frame
#
#     a) Nokia Audio Dock, with Caller ID
#     b) Logitech Keyboard, Programmable
#     c) Motorola Headset, with Caller ID
#     d) Belkin Flash Drive, Bluetooth

# %%
prof = df['Profit']
prof
# Out:
# 0       7
# 1      15
# 2     109
# 3     168
# 4     -11
#      ...
# 63     40
# 64     54
# 65     12
# 66     15
# 67     19
# Name: Profit, Length: 61, dtype: int64

# %%
filtered = prof > 0
filtered
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
#       ...
# 63     True
# 64     True
# 65     True
# 66     True
# 67     True
# Name: Profit, Length: 61, dtype: bool

# %%
#your code here
df4 = df[filtered]
df4
# Out:
#            Order ID                                       Product Name  \
# 0   AZ-2011-1029887         Novimex Color Coded Labels, 5000 Label Set
# 1    AZ-2011-107716                     Deflect-O Door Stop, Erganomic
# 2   AZ-2011-1087704                      Belkin Flash Drive, Bluetooth
# 3   AZ-2011-1372644                         Panasonic Printer, Durable
# 5   AZ-2011-1114253                         Tenex Stacking Tray, Black
# 6   AZ-2011-1116129                     Avery Binding Machine, Durable
# 7   AZ-2011-1137571                  Stiletto Letter Opener, Easy Grip
# 8   AZ-2011-1174243                   Nokia Audio Dock, with Caller ID
# 9    AZ-2011-122598               Avery Removable Labels, Alphabetical
# 10  AZ-2011-1229073                         Deflect-O Door Stop, Black
# 11  AZ-2011-1240916                         Boston Canvas, Water Color
# 12  AZ-2011-1253407                     Safco Stackable Bookrack, Pine
# ...

# %%
len(df), len(df4)
# Out:
# (61, 52)

# %%
df4_cat = df4['Category']
df4_cat
# Out:
# 0     Office Supplies
# 1           Furniture
# 2          Technology
# 3          Technology
# 5           Furniture
# 6     Office Supplies
# 7     Office Supplies
# 8          Technology
# 9     Office Supplies
# 10          Furniture
# 11    Office Supplies
# 12          Furniture
# 14    Office Supplies
# 15    Office Supplies
# 16    Office Supplies
# 17          Furniture
# 18    Office Supplies
# 19    Office Supplies
# 20         Technology
# 22    Office Supplies
# 23    Office Supplies
# 26          Furniture
# 27    Office Supplies
# 30         Technology
# 31          Furniture
# 32    Office Supplies
# 33         Technology
# 35    Office Supplies
# 36    Office Supplies
# 37    Office Supplies
# 38    Office Supplies
# 39         Technology
# 42    Office Supplies
# 46    Office Supplies
# 47    Office Supplies
# 48    Office Supplies
# 50    Office Supplies
# 51    Office Supplies
# 52         Technology
# 53    Office Supplies
# 56          Furniture
# ...

# %%
filtered = (df4_cat == 'Technology')
filtered
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 22    False
# 23    False
# 26    False
# 27    False
# 30     True
# 31    False
# 32    False
# 33     True
# 35    False
# 36    False
# 37    False
# 38    False
# 39     True
# 42    False
# 46    False
# 47    False
# 48    False
# 50    False
# 51    False
# 52     True
# 53    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# 63     True
# 64    False
# 65    False
# 66    False
# 67    False
# Name: Category, dtype: bool

# %%
df4 = df4.loc[filtered]
df4 # all rows of category columns are technology
# Out:
#            Order ID                      Product Name  Discount  Sales  \
# 2   AZ-2011-1087704     Belkin Flash Drive, Bluetooth       0.0    294
# 3   AZ-2011-1372644        Panasonic Printer, Durable       0.0    800
# 8   AZ-2011-1174243  Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840  Motorola Headset, with Caller ID       0.0    957
# 30  AZ-2011-1410648      Nokia Smart Phone, Full Size       0.0   1908
# 33  AZ-2011-1445262       Apple Smart Phone, Cordless       0.0    636
# 39  AZ-2011-1536006   Logitech Keyboard, Programmable       0.0    666
# 52  AZ-2011-1722024            Cisco Audio Dock, VoIP       0.0    364
# 63  AZ-2011-1967754      Logitech Numeric Keypad, USB       0.0     93
#
#     Profit  Quantity    Category Sub-Category Order no  no_of_digits
# 2      109         7  Technology  Accessories  1087704             7
# 3      168         3  Technology     Machines  1372644             7
# ...

# %%
quan = df4['Quantity']
quan
# Out:
# 2      7
# 3      3
# 8      8
# 20    12
# 30     3
# 33     1
# 39     9
# 52     2
# 63     2
# Name: Quantity, dtype: int64

# %%
prof = df4['Profit']
prof
# Out:
# 2     109
# 3     168
# 8     200
# 20    316
# 30    820
# 33    140
# 39     66
# 52    142
# 63     40
# Name: Profit, dtype: int64

# %%
df4['Profit_per_qty'] = prof / quan
df4
# Out:
# <ipython-input-38-47cd622c9ba5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Profit_per_qty'] = prof / quan
#            Order ID                      Product Name  Discount  Sales  \
# 2   AZ-2011-1087704     Belkin Flash Drive, Bluetooth       0.0    294
# 3   AZ-2011-1372644        Panasonic Printer, Durable       0.0    800
# 8   AZ-2011-1174243  Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840  Motorola Headset, with Caller ID       0.0    957
# 30  AZ-2011-1410648      Nokia Smart Phone, Full Size       0.0   1908
# 33  AZ-2011-1445262       Apple Smart Phone, Cordless       0.0    636
# 39  AZ-2011-1536006   Logitech Keyboard, Programmable       0.0    666
# ...

# %%
low_prof = df4.sort_values(by = 'Profit_per_qty', ascending = True)
low_prof
# Out:
#            Order ID                      Product Name  Discount  Sales  \
# 39  AZ-2011-1536006   Logitech Keyboard, Programmable       0.0    666
# 2   AZ-2011-1087704     Belkin Flash Drive, Bluetooth       0.0    294
# 63  AZ-2011-1967754      Logitech Numeric Keypad, USB       0.0     93
# 8   AZ-2011-1174243  Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840  Motorola Headset, with Caller ID       0.0    957
# 3   AZ-2011-1372644        Panasonic Printer, Durable       0.0    800
# 52  AZ-2011-1722024            Cisco Audio Dock, VoIP       0.0    364
# 33  AZ-2011-1445262       Apple Smart Phone, Cordless       0.0    636
# 30  AZ-2011-1410648      Nokia Smart Phone, Full Size       0.0   1908
#
#     Profit  Quantity    Category Sub-Category Order no  no_of_digits  \
# 39      66         9  Technology  Accessories  1536006             7
# 2      109         7  Technology  Accessories  1087704             7
# ...

# %%
prof_col = low_prof[['Product Name', 'Profit_per_qty']]
prof_col
# Out:
#                         Product Name  Profit_per_qty
# 39   Logitech Keyboard, Programmable        7.333333
# 2      Belkin Flash Drive, Bluetooth       15.571429
# 63      Logitech Numeric Keypad, USB       20.000000
# 8   Nokia Audio Dock, with Caller ID       25.000000
# 20  Motorola Headset, with Caller ID       26.333333
# 3         Panasonic Printer, Durable       56.000000
# 52            Cisco Audio Dock, VoIP       71.000000
# 33       Apple Smart Phone, Cordless      140.000000
# 30      Nokia Smart Phone, Full Size      273.333333

# %%
# Ans.
prof_col.iloc[0,0]
# Out:
# 'Logitech Keyboard, Programmable'
