# %% [markdown]
# What is a Data Warehouse?
# -------------
#
#     A data warehouse is a collection of data.
#
# *It has the following* `properties`:
#
# - **Subject-oriented**: A data warehouse should contain information about a few well-defined subjects rather than the enterprise.
#
# - **Integrated**: A data warehouse is an integrated repository of data. It contains information from various systems within an organisation.
#
# - **Non-volatile**: The data values in a database cannot be changed without a valid reason.
#
# - **Time-variant**: A data warehouse contains historical data for analysis.

# %% [markdown]
# Data Warehousing
# ------
#
# A data warehouse holds data from multiple sources in a single repository or location.
#
# For a typical organisation, what are the benefits of a data warehouse?
#
# More than one option may be correct.
#
# -----------
#
# (`All Options Correct`)
#
# It helps integrate data from multiple source systems, enabling a central view across the enterprise.
#
#     ✓ Correct
#     Feedback:
#
#     Correct. A data warehouse is an integrated repository of data.
#     It contains data from different data sources.
#
#
# Data persistence. A data warehouse stores current as well as historical data, which may not be the case with locally stored files in MS Excel, etc.
#
#     ✓ Correct
#     Feedback:
#
#     Correct. A data warehouse stores historical data.
#     It is time-variant and contains information on past data.
#
#
# It enables analysts to create holistic business reports easily using information from multiple departments.
#
#     ✓ Correct
#     Feedback:
#
#     Correct. Since a data warehouse is an integrated repository,
#     it contains data on the various aspects of the business,
#     thus helping analysts draw deeper insights.
#
#
# It speeds up the analysis and the processing of data as compared with having isolated databases.
#
#     ✓ Correct
#     Feedback:
#
#     Correct. The data is stored in a way that makes analysis easy,
#     and it gives a full view of the entire organisation.

# %% [markdown]
# Facts and Dimensions
# ----------
#
# Consider a bank that has thousands of ATMs across India.
#
# In every transaction, the following variables are recorded:
#
# 1. Withdrawal amount
# 2. Account balance after withdrawal
# 3. Transaction charge amount
# 4. Customer ID
# 5. ATM ID
# 6. Date of withdrawal
#
# Which of the variables above are fact variables (select all that apply)?
#
#     Withdrawal amount
#
#     Account balance after withdrawal
#
#     Transaction charge amount
#
#     Customer ID
#
#     ATM ID
#
#     Date of withdrawal
#
# ----------
#
#     1, 2, 3
#
#     ✓ Correct
#     Feedback:
#
# Correct. it is a fact variable as it contains numerical data.

# %% [markdown]
# Dimensional Modelling
# -----------
#
# What are the benefits of having dimension variables apart from facts?
#
# More than one option may be correct.
#
#     ✓ Correct
#       It helps with performing various types of analyses,
#       such as sector-wise, country-wise or funding-type-based analyses.
#
#       It helps in summarising the fact variables by calculating
#       their sum, average, range, etc.
#
#     ✓ Correct
#       It helps with extracting specific, useful information,
#       such as the total investment made in the Automobile
#       sector in India between 2014 and 2015.
#
# ------
#
# `Feedback`:
#
# Correct. This activity needs metadata along with the fact data.

# %% [markdown]
# Star Schema
# ------------
#
# In a star schema, what is the name of the table that contains the metadata that is needed for analysing numerical/quantitative data?
#
#     Fact table
#
#     Dimension table
#
#     All the tables of the schema
#
#     None of the above
#
# ---------
#
#     Dimension table
#
#     ✓ Correct
#     Feedback:
#
# Correct. Dimension variables describe the fact data - they are data about data.

# %% [markdown]
# OLAP vs OLTP
# -----------
#
# Which of the following statement(s) is/are true?
#
# More than one option may be correct.
#
#     In OLAP systems, data is taken from a single data source.
#
#     Compared with OLTP, OLAP systems use complex queries to perform tasks,
#     because in OLAP, we perform analysis on various tables and
#     it needs complex queries.
#
#     OLAP systems use ETL.
#
#     Schemas are an essential part of creating OLAP systems.
#
# --------
#
#     Compared with OLTP, OLAP systems use complex queries to perform tasks,
#     because in OLAP, we perform analysis on various tables and
#     it needs complex queries.
#
#     ✓ Correct
#     Feedback:
#
# OLTP systems use simple queries for adding, deleting, updating and retrieving data.
#
# Relatively complex queries are used in OLAP involving aggregations.
#
#     OLAP systems use ETL.
#
#     ✓ Correct
#     Feedback:
#
# OLAP systems need data from different data sources.
#
# Before all the data is collected, we need to ensure that
#
# the interpretation of the data from different data sources is the same and
#
# that it is loaded into the data warehouse structure.
#
#     Schemas are an essential part of creating OLAP systems.
#
#     ✓ Correct
#     Feedback:
#
# Schema diagrams are essential for creating a data warehouse design.
#
# They indicate how the fact and dimension tables will be connected.

# %% [markdown]
# OLAP vs OLTP
# --------
#
# List the types of databases that are used to perform each of the following operations:
#
# 1. Making a purchase
# 2. Withdrawing cash from an ATM
# 3. Finding the average sales of a local store
# 4. Finding profits by region for a specific product of a food MNC
#
#
#     1 - Transactional,
#     2 - Transactional,
#     3 - Transactional and data warehouse,
#     4 - Data warehouse
#
#     1 - Data warehouse,
#     2 - Transactional,
#     3 - Data warehouse,
#     4 - Data warehouse
#
#     1 - Transactional,
#     2 - Transactional,
#     3 - Transactional and data warehouse,
#     4 - Transactional
#
#     1 - Data warehouse,
#     2 - Transactional,
#     3 - Transactional and data warehouse,
#     4 - Data warehouse
#
# ----------
#
#     1 - Transactional,
#     2 - Transactional,
#     3 - Transactional and data warehouse,
#     4 - Data warehouse
#
#     ✓ Correct
#     Feedback:
#
# The average sales can be computed by using either the local sales database of the store or a larger data warehouse of the entire organisation to which the store belongs.

# %% [markdown]
# OLAP vs OLTP
# ----------
#
# Choose the correct statement from the following options given below:
#
#     Transactional databases and data warehouse databases use a similar front-end interface.
#
#     Dimension modelling is used to create a transactional database.
#
#     Data is stored differently in a transactional database
#     and a data warehouse database.
#
#     A star schema is used for creating a transactional database.
#
# --------
#
#     Data is stored differently in a transactional database
#     and a data warehouse database.
#
#     ✓ Correct
#     Feedback:
#
# The objective of a transactional database is to ease the CRUD operations.
#
# For this, it is better if the data is highly normalised and is in separate tables to avoid redundancy.
#
# But for a data warehouse, this is not a good system as you need to analyse a lot of metadata.

# %% [markdown]
# # **SETL**: Select, Extract, Transform and Load.
#
# ----------
#
# - **Select**: Identification of the data that you want to analyse
#
# - **Extract**: Connecting to the particular data source and pulling out the data
#
# - **Transform**: Modifying the extracted data to standardise it
#
# - **Load**: Pushing the data into the data warehouse

# %% [markdown]
# SETL
# ----
#
# Suppose you have a table of Indian athletes containing two columns Height (in m) and Weight (in kg).
#
# You are asked to add another column **BMI** (Body Mass Index).
#
# BMI is calculated using the following formula:
#
#     BMI = Weight / (Height)^2
#
# Which operation would you be performing here?
#
#     Select
#
#     Extract
#
#     Transform
#
#     Load
#
# ---------
#
#     Transform
#
#     ✓ Correct
#     Feedback:
#
# During Transform, you transform the data to get it in the required shape for further analysis.
#
# Here, the addition of another column (BMI) makes analysis easier -
#
# *for example*, you can easily determine if an athlete is underweight, fit, overweight or obese
#
# by simply looking at the values of just this one column.

# %% [markdown]
# # Entity constraints are of the following different types:
#
# ----
#
# - **Unique**: This constraint is used for columns that need unique values. For example, 'employee ids' should be unique in an 'employees' table.
#
# - **Null**: This constraint is used to determine the columns that can have null values. For example, an employee may not need to specify their location, which means the 'location' column can have null values in an 'employees' table.
#
# - **Primary Key**: This constraint is used to determine the column that uniquely identifies a table. For example, 'employee ids' uniquely identify every employee. Two employees may have the same name or the same salary, but not the same employee id.

# %% [markdown]
# Use of Entity Constraints
# --------
#
# Entity constraints are used to:
#
#     Improve the quality of data entered for a specific property.
#
#     Control who is allowed access to the data.
#
#     Ensure that duplicate records are not entered into the table.
#
#     Prevent users from changing the values stored in the table.
#
# ----------
#
#     Ensure that duplicate records are not entered into the table.
#
#     ✓ Correct
#     Feedback:
#
# The UNIQUE constraint is a type of entity constraint that ensures uniqueness of a column in a table.

# %% [markdown]
# Primary Keys
# -------
#
# A primary key constraint always enforces both the UNIQUE and NOT NULL constraints.
#
#     True
#
#     False
#
# ---------
#
#     True
#
#     ✓ Correct
#     Feedback:
#
# Since a column that is a primary key cannot contain duplicate and null values,
#
# it enforces both the UNIQUE and NOT NULL constraints automatically.

# %% [markdown]
# # Referential Constraints

# %% [markdown]
# An Example of a Referential Constraint
# ----------
#
# Which of the following scenarios would require using a referential constraint?
#
#     All phone numbers should contain the area code.
#
#     Certain fields are mandatory to fill (such as phone number) before
#     the record is accepted in a database.
#
#     Information on a customer must be known before anything can be sold to
#     that customer, so that you can refer to other fields to get the
#     information of the customers.
#
#     When entering the card number for payment, the user must input a 16-digit number.
#
# ---------
#
#     Information on a customer must be known before anything can be sold to
#     that customer, so that you can refer to other fields to get the
#     information of the customers.
#
#     ✓ Correct
#     Feedback:
#
# This would constitute a foreign key constraint, which is a referential constraint.
#
# This is because customer details are required before a particular product
#
# can be associated with the customer who placed the order for that product.

# %% [markdown]
# Primary Key vs Foreign Key
# --------
#
# Mention two differences between a primary key and a foreign key.
#
# -------
#
# - **Primary Key**: Uniquely identifies records within a table.
#
# - **Foreign Key**: Establishes relationships between tables and ensures referential integrity.
#
#
#     Suggested Answer
#
#
# 1. A primary key identifies each row in a table uniquely, whereas a foreign key uniquely identifies a row in the same table or in another table.
#
# 2. Only one primary key is allowed in a table, whereas it can have multiple foreign keys.

# %% [markdown]
# # Semantic Constraints
#
# **For example**,
#
# All the mobile numbers in India start with '+91', followed by 10 digits.
#
# Using a semantic constraint for this requirement ensures that we do not get incorrect data for any row.
#
# A row with a phone number +*91987654321* would not be allowed to enter the database as it has only 9 digits after the country code.

# %% [markdown]
# Semantic Constraints
# ---------
#
# Consider a column containing the blood groups of various blood donors.
#
# Which of the following options is an example of a semantic constraint in this case?
#
# More than one option may be correct.
#
#     A blood group can contain one of the following values: A, B, AB and O.
#
#     A blood group can contain only characters.
#
#     A blood group cannot have null values.
#
#     Two or more donors can have the same blood group.
#
# ---------
#
#     A blood group can contain one of the following values: A, B, AB and O.
#
#     A blood group can contain only characters.
#
#     ✓ Correct
#     Feedback:
#
# This is a semantic constraint as it ensures that only particular values can belong to the 'Blood Group' column.

# %% [markdown]
# Types of Constraints
# ----------
#
# Which of the following constraints does not enforce uniqueness?
#
#     Primary Key
#
#     Foreign Key
#
#     UNIQUE
#
#     None of the above
#
# --------
#
#     Foreign Key
#
#     ✓ Correct
#     Feedback:
#
# Foreign key constraints identify and enforce the relationships between tables.
#
# A column that is a foreign key can contain duplicate values.

# %% [markdown]
# Types of Constraints
# -------
#
# Allowing only certain values in a column and ensuring that the values are in a specified format or belong to a certain range are examples of:
#
#     Referential Constraints
#
#     Semantic Constraints
#
#     Entity Constraints
#
#     None of the above
#
# -------
#
#     Semantic Constraints
#
#     ✓ Correct
#     Feedback:
#
# Semantic constraints ensure that the data is present in the correct format in a table.

# %% [markdown]
# Entity Types and Attributes
# ---------
#
# Your mobile phone can be considered an entity type having different attributes such as Model, Launch Date and Operating System. Can you think of three more such attributes?
#
#     Ans.
#
# 1. Screen Size
# 2. Internal Storage
# 3. Camera Resolution
#
#
#     Suggested Answer
#
#
# 1. RAM
# 2. Storage space
# 3. Total cost

# %% [markdown]
# # The constituents of an ERD are as follows:
#
# -----
#
# - **Entity Type/Entity**: It is nothing but a table in the schema. For example, 'orders' and 'payments' are both entity types.
#
# - **Attribute**: It is a column in an entity type. For example, 'orderNumber' is an attribute in the 'orders' entity type.
#
# - **Relationship Types**: They are the lines between the tables. They define the relationships among the tables. These can be of various types based on their cardinalities, i.e., one-to-one, one-to-many, many-to-many, etc.

# %% [markdown]
# Cardinality
# ----------
#
# How would you describe a relationship between the following two tables:
#
# a 'Students' table containing student details and a 'Courses' table containing course details?
#
#     Zero to one
#
#     One to one
#
#     One to many
#
#     Many to many
#
# ---------
#
#     Many to many
#
#     ✓ Correct
#     Feedback:
#
# A many-to-many relationship would imply that a student can take up more than one course,
#
# while a course can be taken up by more than one student.

# %% [markdown]
# Examples of Self-Referential Relationships
# -------------
#
# As you saw in the video, an 'employees' table can have a self-referential relationship since the manager of an employee is also an employee.
#
# Can you think of another example of a table that can have a self-referential relationship?
#
#     Ans.
#
# A category "Electronics" can have subcategories like "Computers,"
#
# which can further have subcategories like "Laptops" or "Desktops."
#
# This self-referential relationship allows for organizing and nesting categories within each other.
#
#     Suggested Answer
#
# A good example would be that of a table containing job referrals.
#
# Imagine you have joined Amazon through a referral given by one of your friends.
#
# In this case, the 'Referrals' table would contain your employee id as well as the referrer's employee id.
#
# Note that the referrer is an employee himself/herself.
#
# <br>
# <center>
#
# **`Referrals`**
#
# EmpID | EmpName | ReferrerID
# --- | --- | ---
# 1234 | Amitabh Bachchan | NULL
# 3124 | Aamir Khan | 1234
# 2134 | Shah Rukh Khan | 1234
#
# </center>

# %% [markdown]
# Entity-Relationship Diagram – Classic Models
# ----------
#
# ![ss](https://images.upgrad.com/d821afe0-7432-41d1-a761-0ca5ad2b019e-classicmodels.png)
#
# Refer to the ERD given above for the 'classic models' data set. Which of the following statement(s) is/are correct?
#
#     An employee is associated with zero or more customers,
#     whereas a customer is associated with zero or one employee.
#
#     A customer is associated with zero or more employees,
#     whereas an employee is associated with zero or one customer.
#
#     A customer can have zero or more orders,
#     whereas an order is associated with one and only one customer.
#
#     An order corresponds to zero or more customers,
#     whereas a customer can have one and only one order.
#
# ---------
#
#     An employee is associated with zero or more customers,
#     whereas a customer is associated with zero or one employee.
#
#     A customer can have zero or more orders,
#     whereas an order is associated with one and only one customer.
#
#     ✓ Correct
#     Feedback:
#
# The notation is zero followed by a crow’s foot at the orders’ end and one followed by one at the customers’ end.

# %% [markdown]
# Comprehension
# -----------
#
# Suppose you are given a data set of a college.
#
# This data set mainly includes the following four tables:
#
# - **Student**: This table contains information about the students, such as student id, name, range of marks scored in the exam, year of graduation and branch id.
#
#   ![ss](https://images.upgrad.com/fb08a49b-d7a7-4ac7-8012-51f068cbd97f-img22.PNG)
#
# - **Branch**: This table includes the different branches present in the college, such as Electrical, Mechanical, Civil, Computer Science, Chemical, along with branch ids.
#
#   ![ss](https://images.upgrad.com/3f28302c-88c0-49be-9b6c-69b05e68f65e-img23.PNG)
#
# - **HoD**: This table contains information about the HoDs, i.e., Head of the Departments of the different branches.
#
#   This information includes HoD name, duration of service as HoD, branch id of the branch in which a particular person is/was HoD and their contact information.
#
#   ![ss](https://images.upgrad.com/dd9af3fc-5f0e-40fe-82d5-3e7e3a65b61a-img24.PNG)
#
# - **Marks**: This table contains the mapping of the range of marks with the grades awarded.
#
#   ![ss](https://images.upgrad.com/7dab1bb1-d9b5-4cfa-a82e-56f426118fae-img25.PNG)
#
#
#     You can consider the following entries as examples of each of the table formats above.
#
#
# **Student**
#
# ![ss](https://images.upgrad.com/aeef6574-b865-4833-90d2-84501f20018c-img26.PNG)
#
# **Branch**
#
# ![ss](https://images.upgrad.com/b05699b2-6662-477e-b763-6f66283a7d7e-img27.PNG)
#
# **HoD**
#
# ![ss](https://images.upgrad.com/a4014135-4975-47dc-9f50-70a0e2f58f45-img28.PNG)
#
# **Marks**
#
# ![ss](https://images.upgrad.com/a815acce-65e0-4459-8d9f-7b760360ac6a-img29.PNG)
#
# Answer the following questions based on the information in the tables given above.

# %% [markdown]
# Primary Key
# ---------
#
# Which of the following fields can be a possible primary key of the ‘marks’ table?
#
# Multiple options can be correct.
#
#     grades
#
#     marks_range
#
#     There is no primary key in this table.
#
# ----------
#
#     grades
#     marks_range
#
#     ✓ Correct
#     Feedback:
#
# Each row can be identified uniquely by marks_range and, hence, it can be the primary key.

# %% [markdown]
# Foreign Key
# ---------
#
# What is/are the foreign key(s) in the ‘Student’ table? Multiple options can be correct.
#
#     student_id
#
#     marks_range
#
#     year
#
#     branch_id
#
# ---------
#
#     marks_range
#
#     ✓ Correct
#     Feedback:
#
# Correct. ‘marks_range’, which refers to the `‘Marks’` table, is the foreign key of this table.
#
#     branch_id
#
#     ✓ Correct
#     Feedback:
#
# Correct. ‘branch_id’, which refers to the `‘Branch’` table, is the foreign key of this table

# %% [markdown]
# Primary and Foreign Keys
# -------
#
# Choose the correct statements for the ‘HoD’ table from the options given below.
#
# Multiple options can be correct.
#
#     ‘branch_id’ can be the primary key of the ‘HoD’ table.
#
#     ‘branch_id’ is the foreign key of the ‘HoD’ table.
#
#     ‘branch_id’ and ‘year_of_service_as_HoD’ can be the
#     composite primary key of the ‘HoD’ table.
#
#     ‘branch_id’ and ‘branch_HoD_name’ can be the
#     composite primary key of the ‘HoD’ table.
#
# ------------
#
#     ‘branch_id’ is the foreign key of the ‘HoD’ table.
#
#     ✓ Correct
#     Feedback:
#
# ‘branch_id’ is the foreign key of the ‘HoD’ table, since this is the primary key of the ‘Branch’ table.
#
#
#     ‘branch_id’ and ‘year_of_service_as_HoD’ can be the
#     composite primary key of the ‘HoD’ table.
#
#     ✓ Correct
#     Feedback:
#
# ‘branch_id’ alone cannot be the primary key, since there can be multiple HoDs for the same branch id for different years.
#
# But if you combine branch id with year, then it will identify the rows in the table uniquely.
#
# Hence, ‘branch_id’ and ‘year_of_service_as_HoD’ can be the composite primary key.

# %% [markdown]
# Primary and Foreign Keys
# ----------
#
# Which of the following statements could be correct?
#
#     In the ‘Branch’ table, ‘branch_id’ can have NULL values.
#
#     In the ‘Student’ table, ‘marks_range’ can have NULL values.
#
#     In the ‘Student’ table, ‘branch_id’ cannot have NULL values.
#
#     In the ‘HoD’ table, ‘branch_id’ can have NULL values.
#
# -----------
#
#     In the ‘Student’ table, ‘marks_range’ can have NULL values.
#
#     ✓ Correct
#     Feedback:
#
# In the ‘Student’ table, ‘marks_range’ is the foreign key, which refers to the ‘Marks’ table; hence, it can have null values.

# %% [markdown]
# Fact Variables
# -------
#
# How many **fact variables** are present in the '`cust_dimen`' table used in the market star schema explained in the video?
#
# **Note**: Fact variables are those variables that have some numeric values in them.
#
#     cust_dimen
#
# Customer_Name
#
# City
#
# State
#
# Customer_Segment
#
# Cust_id
#
# ---------
#
# `Ans`. 0

# %% [markdown]
# Fact or Dimension?
# --------
#
# Which type of variable is 'Order_ID' in the 'shipping_dimen' table?
#
# **shipping_dimen**
#
# Ship_id VARCHAR(12)
#
# Order_ID INT(11)
#
# Ship_Mode VARCHAR(25)
#
# Ship_Date DATE
#
#
#     Fact Variable
#
#     Dimension Variable
#
# ---------
#
#     Dimension Variable
#
#     ✓ Correct
#     Feedback:
#
# Order_ID is a dimension variable as it describes the data qualitatively.
#
# A shipment having a particular order id is associated with an order placed by a customer.

# %% [markdown]
# Summary
# ------
#
# In this session, you learnt the following:
#
# - What a data warehouse is
# - The differences between a data warehouse and a transactional database
# - OLAP (Online Analytical Processing) systems are Subject-oriented, Integrated, Non-volatile and Time-variant
# - A data warehouse provides an integrated view of the entire organisation and the data is organised for carrying out analysis efficiently
# - Facts and dimensions and how to arrange them in order to design a data warehouse
# - Dimension tables act as metadata, which is data about data, and enhance the facts table to enhance the insights from the data
# - What a star schema is
# - The advantages of having a star schema in a database
# - The SETL process: Select, Extract, Transform and Load
# - The different types of constraints: Entity, Referential and Semantic constraints
# - ERDs and their constituents
#
# Key Takeaways
# ----------
#
# What are your three key takeaways from this session?
#
# 1. **Entity Representation**: ERDs use entities to represent real-world objects, concepts, or things that have attributes.
#
#   Entities are depicted as rectangles in the diagram and represent the tables in a database.
#
# 2. **Relationship Modeling**: ERDs illustrate the relationships between entities.
#
#   Relationships represent how entities are connected or associated with each other.
#
#   Common types of relationships include one-to-one, one-to-many, and many-to-many.
#
#   These relationships are shown with lines connecting the related entities.
#
# 3. **Attribute Specification**: ERDs include attributes, which describe the properties or characteristics of an entity.
#
#   Attributes are depicted as ovals or ellipses within the entity rectangles and provide details about the data that is stored for each entity.
#
#   Attributes can be simple (such as a single value) or composite (made up of multiple sub-attributes).
#
#   They help define the structure and content of the database tables.
#
# Overall, ERDs serve as a visual tool to design, analyze, and communicate the structure and relationships within a database system.
#
# They are essential for database developers, designers, and stakeholders to understand and document the database schema.
