# %% [markdown]
# ## [Practice Exercise 2](https://jovian.com/chetanrg05/practiceexercise2movies)

# %% [markdown]
# In this assignment, you will try to find some interesting insights into a few movies released between 1916 and 2016, using Python. You will have to download a movie dataset, write Python code to explore the data, gain insights into the movies, actors, directors, and collections, and submit the code.

# %% [markdown]
# #### Some tips before starting the assignment
#
# 1. Identify the task to be performed correctly, and only then proceed to write the required code. Don’t perform any incorrect analysis or look for information that isn’t required for the assignment.
# 2. In some cases, the variable names have already been assigned, and you just need to write code against them. In other cases, the names to be given are mentioned in the instructions. We strongly advise you to use the mentioned names only.
# 3. Always keep inspecting your data frame after you have performed a particular set of operations.
# 4. There are some checkpoints given in the IPython notebook provided. They're just useful pieces of information you can use to check if the result you have obtained after performing a particular task is correct or not.
# 5. Note that you will be asked to refer to documentation for solving some of the questions. That is done on purpose for you to learn new commands and also how to use the documentation.

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ### Task 1: Reading and Inspection
#
# **Subtask 1.1: Import and read**
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
# Write your code for importing the csv file here
movies = pd.read_csv('Movies.csv')
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 3848  Color      Shane Carruth                   143.0      77.0
# 3849  Color   Neill Dela Llana                    35.0      80.0
# 3850  Color   Robert Rodriguez                    56.0      81.0
# 3851  Color       Edward Burns                    14.0      95.0
# 3852  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# 1                       563.0                  1000.0       Orlando Bloom
# 2                         0.0                   161.0        Rory Kinnear
# 3                     22000.0                 23000.0      Christian Bale
# 4                       475.0                   530.0     Samantha Morton
# ...                       ...                     ...                 ...
# 3848                    291.0                     8.0      David Sullivan
# 3849                      0.0                     0.0     Edgar Tancangco
# 3850                      0.0                     6.0     Peter Marquardt
# 3851                      0.0                   133.0  Caitlin FitzGerald
# 3852                     16.0                    16.0    Brian Herzlinger
#
#       actor_1_facebook_likes        gross  \
# 0                     1000.0  760505847.0
# 1                    40000.0  309404152.0
# 2                    11000.0  200074175.0
# 3                    27000.0  448130642.0
# 4                      640.0   73058679.0
# ...                      ...          ...
# 3848                   291.0     424760.0
# 3849                     0.0      70071.0
# 3850                   121.0    2040920.0
# 3851                   296.0       4584.0
# 3852                    86.0      85222.0
#
#                                    genres  ... num_user_for_reviews language  \
# 0         Action|Adventure|Fantasy|Sci-Fi  ...               3054.0  English
# 1                Action|Adventure|Fantasy  ...               1238.0  English
# 2               Action|Adventure|Thriller  ...                994.0  English
# 3                         Action|Thriller  ...               2701.0  English
# 4                 Action|Adventure|Sci-Fi  ...                738.0  English
# ...                                   ...  ...                  ...      ...
# 3848                Drama|Sci-Fi|Thriller  ...                371.0  English
# 3849                             Thriller  ...                 35.0  English
# 3850  Action|Crime|Drama|Romance|Thriller  ...                130.0  Spanish
# 3851                         Comedy|Drama  ...                 14.0  English
# 3852                          Documentary  ...                 84.0  English
#
#           country  content_rating       budget  title_year  \
# 0             USA           PG-13  237000000.0      2009.0
# 1             USA           PG-13  300000000.0      2007.0
# 2              UK           PG-13  245000000.0      2015.0
# 3             USA           PG-13  250000000.0      2012.0
# 4             USA           PG-13  263700000.0      2012.0
# ...           ...             ...          ...         ...
# 3848          USA           PG-13       7000.0      2004.0
# 3849  Philippines       Not Rated       7000.0      2005.0
# 3850          USA               R       7000.0      1992.0
# 3851          USA       Not Rated       9000.0      2011.0
# 3852          USA              PG       1100.0      2004.0
#
#      actor_2_facebook_likes imdb_score  aspect_ratio movie_facebook_likes
# 0                     936.0        7.9          1.78                33000
# 1                    5000.0        7.1          2.35                    0
# 2                     393.0        6.8          2.35                85000
# 3                   23000.0        8.5          2.35               164000
# 4                     632.0        6.6          2.35                24000
# ...                     ...        ...           ...                  ...
# 3848                   45.0        7.0          1.85                19000
# 3849                    0.0        6.3           NaN                   74
# 3850                   20.0        6.9          1.37                    0
# 3851                  205.0        6.4           NaN                  413
# 3852                   23.0        6.6          1.85                  456
#
# [3853 rows x 28 columns]

# %% [markdown]
# **Subtask 1.2: Inspect the dataframe**
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
col = movies.columns
col
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
len(col)
# Out:
# 28

# %%
len(movies)
# Out:
# 3853

# %%
movies.shape
# Out:
# (3853, 28)

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### <font color='white'>Question 1: How many rows and columns are present in the dataframe? </font>
#
# -  <font color='red'>(3821, 26)</font>
# -  <font color='red'>(3879, 28)</font>
# -  <font color='green'>(3853, 28)</font>
# -  <font color='red'>(3866, 26)</font>

# %%
# Ans.
rows, cols = movies.shape
rows, cols
# Out:
# (3853, 28)

# %% [markdown]
# #### <font color='white'>Question 2: How many columns have null values present in them? Try writing a code for this instead of counting them manually.</font>
#
# -  <font color='red'>3</font>
# -  <font color='red'>6</font>
# -  <font color='red'>9</font>
# -  <font color='green'>12</font>

# %%
# np.sum(np.sum(pd.isnull(movies)) > 0)
pd.isnull(movies).sum()
# Out:
# color                         2
# director_name                 0
# num_critic_for_reviews        1
# duration                      1
# director_facebook_likes       0
# actor_3_facebook_likes        6
# actor_2_name                  1
# actor_1_facebook_likes        0
# gross                         0
# genres                        0
# actor_1_name                  0
# movie_title                   0
# num_voted_users               0
# cast_total_facebook_likes     0
# actor_3_name                  6
# facenumber_in_poster          6
# plot_keywords                30
# movie_imdb_link               0
# num_user_for_reviews          0
# language                      3
# country                       0
# content_rating               48
# budget                        0
# title_year                    0
# actor_2_facebook_likes        1
# imdb_score                    0
# aspect_ratio                 72
# movie_facebook_likes          0
# dtype: int64

# %%
# Ans.
np.sum(movies.isnull().sum() > 0)
# Out:
# 12

# %% [markdown]
# ### Task 2: Cleaning the Data
#
# **Subtask 2.1: Drop unecessary columns**
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
#
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Check the 'drop' function in the Pandas library - dataframe.drop(list_of_unnecessary_columns, axis = )
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations

# copied above <li> tags
to_drop = '''color
director_facebook_likes
actor_1_facebook_likes
actor_2_facebook_likes
actor_3_facebook_likes
actor_2_name
cast_total_facebook_likes
actor_3_name
duration
facenumber_in_poster
content_rating
country
movie_imdb_link
aspect_ratio
plot_keywords'''

drop_list = to_drop.split('\n')
drop_list
# Out:
# ['color',
#  'director_facebook_likes',
#  'actor_1_facebook_likes',
#  'actor_2_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'duration',
#  'facenumber_in_poster',
#  'content_rating',
#  'country',
#  'movie_imdb_link',
#  'aspect_ratio',
#  'plot_keywords']

# %%
new_movies = movies.drop(drop_list, axis = 1)
new_movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 3848      Shane Carruth                   143.0     424760.0
# 3849   Neill Dela Llana                    35.0      70071.0
# 3850   Robert Rodriguez                    56.0    2040920.0
# 3851       Edward Burns                    14.0       4584.0
# 3852           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# 3                         Action|Thriller        Tom Hardy
# 4                 Action|Adventure|Sci-Fi     Daryl Sabara
# ...                                   ...              ...
# 3848                Drama|Sci-Fi|Thriller    Shane Carruth
# 3849                             Thriller      Ian Gamazon
# 3850  Action|Crime|Drama|Romance|Thriller  Carlos Gallardo
# 3851                         Comedy|Drama      Kerry Bishé
# 3852                          Documentary      John August
#
#                                     movie_title  num_voted_users  \
# 0                                       Avatar            886204
# 1     Pirates of the Caribbean: At World's End            471220
# 2                                      Spectre            275868
# 3                        The Dark Knight Rises           1144337
# 4                                  John Carter            212204
# ...                                         ...              ...
# 3848                                    Primer             72639
# 3849                                    Cavite               589
# 3850                               El Mariachi             52055
# 3851                                 Newlyweds              1338
# 3852                         My Date with Drew              4285
#
#       num_user_for_reviews language       budget  title_year  imdb_score  \
# 0                   3054.0  English  237000000.0      2009.0         7.9
# 1                   1238.0  English  300000000.0      2007.0         7.1
# 2                    994.0  English  245000000.0      2015.0         6.8
# 3                   2701.0  English  250000000.0      2012.0         8.5
# 4                    738.0  English  263700000.0      2012.0         6.6
# ...                    ...      ...          ...         ...         ...
# 3848                 371.0  English       7000.0      2004.0         7.0
# 3849                  35.0  English       7000.0      2005.0         6.3
# 3850                 130.0  Spanish       7000.0      1992.0         6.9
# 3851                  14.0  English       9000.0      2011.0         6.4
# 3852                  84.0  English       1100.0      2004.0         6.6
#
#       movie_facebook_likes
# 0                    33000
# 1                        0
# 2                    85000
# 3                   164000
# 4                    24000
# ...                    ...
# 3848                 19000
# 3849                    74
# 3850                     0
# 3851                   413
# 3852                   456
#
# [3853 rows x 13 columns]

# %%
row_col = new_movies.shape
row_col
# Out:
# (3853, 13)

# %%
np.sum(new_movies['language'].isnull())
# Out:
# 3

# %%
len(new_movies[new_movies['language'] == 'English'])
# Out:
# 3671

# %% [markdown]
# #### <font color='white'>Question 3: What is the count of columns in the new dataframe? </font>
#
# -  <font color='red'>10</font>
# -  <font color='green'>13</font>
# -  <font color='red'>15</font>
# -  <font color='red'>17</font>

# %%
# Ans.
row_col[1]
# Out:
# 13

# %% [markdown]
# **Subtask 2.2: Inspect Null values**
#
# As you have seen above, there are null values in multiple columns of the dataframe 'movies'. Find out the percentage of null values in each column of the dataframe 'movies'.

# %%
# Write you code here
null_movies = new_movies.isnull().sum()
null_movies
# Out:
# director_name             0
# num_critic_for_reviews    1
# gross                     0
# genres                    0
# actor_1_name              0
# movie_title               0
# num_voted_users           0
# num_user_for_reviews      0
# language                  3
# budget                    0
# title_year                0
# imdb_score                0
# movie_facebook_likes      0
# dtype: int64

# %%
check_max = 100*(null_movies / len(new_movies))
check_max
# Out:
# director_name             0.000000
# num_critic_for_reviews    0.025954
# gross                     0.000000
# genres                    0.000000
# actor_1_name              0.000000
# movie_title               0.000000
# num_voted_users           0.000000
# num_user_for_reviews      0.000000
# language                  0.077861
# budget                    0.000000
# title_year                0.000000
# imdb_score                0.000000
# movie_facebook_likes      0.000000
# dtype: float64

# %%
missing_movies = pd.DataFrame(
    {
      'column_name': new_movies.columns,
      'percent_missing': check_max,
    }, 
    # index = range(len(null_movies)),
)

missing_movies.index.names = ['Index Name']
# missing_movies.index += 1
missing_movies
# Out:
#                                    column_name  percent_missing
# Index Name
# director_name                    director_name         0.000000
# num_critic_for_reviews  num_critic_for_reviews         0.025954
# gross                                    gross         0.000000
# genres                                  genres         0.000000
# actor_1_name                      actor_1_name         0.000000
# movie_title                        movie_title         0.000000
# num_voted_users                num_voted_users         0.000000
# num_user_for_reviews      num_user_for_reviews         0.000000
# language                              language         0.077861
# budget                                  budget         0.000000
# title_year                          title_year         0.000000
# imdb_score                          imdb_score         0.000000
# movie_facebook_likes      movie_facebook_likes         0.000000

# %% [markdown]
# #### <font color='white'>Question 4: Which column has the highest percentage of null values? </font>
#
# -  <font color='green'>language</font>
# -  <font color='red'>genres</font>
# -  <font color='red'>num_critic_for_reviews</font>
# -  <font color='red'>imdb_score</font>

# %%
# Ans.
max_percent_row = np.max(missing_movies['percent_missing'])
movies_column = missing_movies[missing_movies['percent_missing'] == max_percent_row]
movies_column
# Out:
#            column_name  percent_missing
# Index Name
# language      language         0.077861

# %% [markdown]
# **Subtask 2.3: Fill NaN values**
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
new_movies['language'].fillna('English', inplace = True)
new_movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 3848      Shane Carruth                   143.0     424760.0
# 3849   Neill Dela Llana                    35.0      70071.0
# 3850   Robert Rodriguez                    56.0    2040920.0
# 3851       Edward Burns                    14.0       4584.0
# 3852           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# 3                         Action|Thriller        Tom Hardy
# 4                 Action|Adventure|Sci-Fi     Daryl Sabara
# ...                                   ...              ...
# 3848                Drama|Sci-Fi|Thriller    Shane Carruth
# 3849                             Thriller      Ian Gamazon
# 3850  Action|Crime|Drama|Romance|Thriller  Carlos Gallardo
# 3851                         Comedy|Drama      Kerry Bishé
# 3852                          Documentary      John August
#
#                                     movie_title  num_voted_users  \
# 0                                       Avatar            886204
# 1     Pirates of the Caribbean: At World's End            471220
# 2                                      Spectre            275868
# 3                        The Dark Knight Rises           1144337
# 4                                  John Carter            212204
# ...                                         ...              ...
# 3848                                    Primer             72639
# 3849                                    Cavite               589
# 3850                               El Mariachi             52055
# 3851                                 Newlyweds              1338
# 3852                         My Date with Drew              4285
#
#       num_user_for_reviews language       budget  title_year  imdb_score  \
# 0                   3054.0  English  237000000.0      2009.0         7.9
# 1                   1238.0  English  300000000.0      2007.0         7.1
# 2                    994.0  English  245000000.0      2015.0         6.8
# 3                   2701.0  English  250000000.0      2012.0         8.5
# 4                    738.0  English  263700000.0      2012.0         6.6
# ...                    ...      ...          ...         ...         ...
# 3848                 371.0  English       7000.0      2004.0         7.0
# 3849                  35.0  English       7000.0      2005.0         6.3
# 3850                 130.0  Spanish       7000.0      1992.0         6.9
# 3851                  14.0  English       9000.0      2011.0         6.4
# 3852                  84.0  English       1100.0      2004.0         6.6
#
#       movie_facebook_likes
# 0                    33000
# 1                        0
# 2                    85000
# 3                   164000
# 4                    24000
# ...                    ...
# 3848                 19000
# 3849                    74
# 3850                     0
# 3851                   413
# 3852                   456
#
# [3853 rows x 13 columns]

# %% [markdown]
# #### <font color='white'>Question 5: What is the count of movies made in English language after replacing the NaN values with English? </font>
#
# -  <font color='red'>3670</font>
# -  <font color='green'>3674</font>
# -  <font color='red'>3668</font>
# -  <font color='red'>3672</font>

# %%
# Ans.
len(new_movies[new_movies['language'] == 'English'])
# Out:
# 3674

# %% [markdown]
# ### Task 3: Data Analysis
#
# **Subtask 3.1: Change the unit of columns**
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here
# Note: net profit = (gross - budget) / 1000000

# Write your code for creating the profit column here
new_movies['net profit'] = (new_movies['gross'] - new_movies['budget']) / 1000000
new_movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4     Andrew Stanton                   462.0   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# 3                     The Dark Knight Rises           1144337
# 4                               John Carter            212204
#
#    num_user_for_reviews language       budget  title_year  imdb_score  \
# 0                3054.0  English  237000000.0      2009.0         7.9
# 1                1238.0  English  300000000.0      2007.0         7.1
# 2                 994.0  English  245000000.0      2015.0         6.8
# 3                2701.0  English  250000000.0      2012.0         8.5
# 4                 738.0  English  263700000.0      2012.0         6.6
#
#    movie_facebook_likes  net profit
# 0                 33000  523.505847
# 1                     0    9.404152
# 2                 85000  -44.925825
# 3                164000  198.130642
# 4                 24000 -190.641321

# %% [markdown]
# **Subtask 3.2: Find the movies with highest profit**
#
#    1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#    2. Sort the dataframe using the `profit` column as reference. (Find which command can be used here to sort entries from the documentation)
#    3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for sorting the dataframe here
# Write your code to get the top 10 profiting movies here

top10 = new_movies.sort_values(by = 'net profit', ascending = False)
top10.head()
# Out:
#          director_name  num_critic_for_reviews        gross  \
# 0        James Cameron                   723.0  760505847.0
# 28     Colin Trevorrow                   644.0  652177271.0
# 25       James Cameron                   315.0  658672302.0
# 2704      George Lucas                   282.0  460935665.0
# 2748  Steven Spielberg                   215.0  434949459.0
#
#                                 genres         actor_1_name  \
# 0      Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 28    Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 25                       Drama|Romance    Leonardo DiCaprio
# 2704   Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 2748                     Family|Sci-Fi         Henry Thomas
#
#                               movie_title  num_voted_users  \
# 0                                 Avatar            886204
# 28                        Jurassic World            418214
# 25                               Titanic            793059
# 2704  Star Wars: Episode IV - A New Hope            911097
# 2748          E.T. the Extra-Terrestrial            281842
#
#       num_user_for_reviews language       budget  title_year  imdb_score  \
# 0                   3054.0  English  237000000.0      2009.0         7.9
# 28                  1290.0  English  150000000.0      2015.0         7.0
# 25                  2528.0  English  200000000.0      1997.0         7.7
# 2704                1470.0  English   11000000.0      1977.0         8.7
# 2748                 515.0  English   10500000.0      1982.0         7.9
#
#       movie_facebook_likes  net profit
# 0                    33000  523.505847
# 28                  150000  502.177271
# 25                   26000  458.672302
# 2704                 33000  449.935665
# 2748                 34000  424.449459

# %% [markdown]
# **Checkpoint:** You might spot two movies directed by `James Cameron` in the list.

# %%
top10[:5][top10[:5]['director_name'] == 'James Cameron'][['director_name', 'movie_title']]
# Out:
#     director_name movie_title
# 0   James Cameron     Avatar
# 25  James Cameron    Titanic

# %% [markdown]
# #### <font color='white'>Question 6: Which movie is ranked 5th from the top in the list obtained? </font>
#
# -  <font color='green'>E.T. the Extra-Terrestrial</font>
# -  <font color='red'>The Avengers</font>
# -  <font color='red'>The Dark Knight</font>
# -  <font color='red'>Titanic</font>

# %%
# Ans.
ranked_5th = top10.iloc[4]['movie_title'].strip()
ranked_5th
# Out:
# 'E.T. the Extra-Terrestrial'

# %% [markdown]
# **Subtask 3.3: Find IMDb Top 250**
#
# Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
#
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'

IMDb_Top_250 = new_movies.sort_values(by = 'imdb_score', ascending = False)[:250]
IMDb_Top_250.head()
# Out:
#              director_name  num_critic_for_reviews        gross  \
# 1795        Frank Darabont                   199.0   28341469.0
# 3016  Francis Ford Coppola                   208.0  134821952.0
# 2543  Francis Ford Coppola                   149.0   57300000.0
# 64       Christopher Nolan                   645.0  533316061.0
# 325          Peter Jackson                   328.0  377019252.0
#
#                               genres    actor_1_name  \
# 1795                     Crime|Drama  Morgan Freeman
# 3016                     Crime|Drama       Al Pacino
# 2543                     Crime|Drama  Robert De Niro
# 64       Action|Crime|Drama|Thriller  Christian Bale
# 325   Action|Adventure|Drama|Fantasy   Orlando Bloom
#
#                                          movie_title  num_voted_users  \
# 1795                       The Shawshank Redemption           1689764
# 3016                                  The Godfather           1155770
# 2543                         The Godfather: Part II            790926
# 64                                  The Dark Knight           1676169
# 325   The Lord of the Rings: The Return of the King           1215718
#
#       num_user_for_reviews language       budget  title_year  imdb_score  \
# 1795                4144.0  English   25000000.0      1994.0         9.3
# 3016                2238.0  English    6000000.0      1972.0         9.2
# 2543                 650.0  English   13000000.0      1974.0         9.0
# 64                  4667.0  English  185000000.0      2008.0         9.0
# 325                 3189.0  English   94000000.0      2003.0         8.9
#
#       movie_facebook_likes  net profit
# 1795                108000    3.341469
# 3016                 43000  128.821952
# 2543                 14000   44.300000
# 64                   37000  348.316061
# 325                  16000  283.019252

# %%
IMDb_Top_250['Rank'] = range(1, 251)
IMDb_Top_250.head()
# Out:
#              director_name  num_critic_for_reviews        gross  \
# 1795        Frank Darabont                   199.0   28341469.0
# 3016  Francis Ford Coppola                   208.0  134821952.0
# 2543  Francis Ford Coppola                   149.0   57300000.0
# 64       Christopher Nolan                   645.0  533316061.0
# 325          Peter Jackson                   328.0  377019252.0
#
#                               genres    actor_1_name  \
# 1795                     Crime|Drama  Morgan Freeman
# 3016                     Crime|Drama       Al Pacino
# 2543                     Crime|Drama  Robert De Niro
# 64       Action|Crime|Drama|Thriller  Christian Bale
# 325   Action|Adventure|Drama|Fantasy   Orlando Bloom
#
#                                          movie_title  num_voted_users  \
# 1795                       The Shawshank Redemption           1689764
# 3016                                  The Godfather           1155770
# 2543                         The Godfather: Part II            790926
# 64                                  The Dark Knight           1676169
# 325   The Lord of the Rings: The Return of the King           1215718
#
#       num_user_for_reviews language       budget  title_year  imdb_score  \
# 1795                4144.0  English   25000000.0      1994.0         9.3
# 3016                2238.0  English    6000000.0      1972.0         9.2
# 2543                 650.0  English   13000000.0      1974.0         9.0
# 64                  4667.0  English  185000000.0      2008.0         9.0
# 325                 3189.0  English   94000000.0      2003.0         8.9
#
#       movie_facebook_likes  net profit  Rank
# 1795                108000    3.341469     1
# 3016                 43000  128.821952     2
# 2543                 14000   44.300000     3
# 64                   37000  348.316061     4
# 325                  16000  283.019252     5

# %%
IMDb_Top_250 = IMDb_Top_250[IMDb_Top_250['num_voted_users'] > 25000]
IMDb_Top_250.head()
# Out:
#              director_name  num_critic_for_reviews        gross  \
# 1795        Frank Darabont                   199.0   28341469.0
# 3016  Francis Ford Coppola                   208.0  134821952.0
# 2543  Francis Ford Coppola                   149.0   57300000.0
# 64       Christopher Nolan                   645.0  533316061.0
# 325          Peter Jackson                   328.0  377019252.0
#
#                               genres    actor_1_name  \
# 1795                     Crime|Drama  Morgan Freeman
# 3016                     Crime|Drama       Al Pacino
# 2543                     Crime|Drama  Robert De Niro
# 64       Action|Crime|Drama|Thriller  Christian Bale
# 325   Action|Adventure|Drama|Fantasy   Orlando Bloom
#
#                                          movie_title  num_voted_users  \
# 1795                       The Shawshank Redemption           1689764
# 3016                                  The Godfather           1155770
# 2543                         The Godfather: Part II            790926
# 64                                  The Dark Knight           1676169
# 325   The Lord of the Rings: The Return of the King           1215718
#
#       num_user_for_reviews language       budget  title_year  imdb_score  \
# 1795                4144.0  English   25000000.0      1994.0         9.3
# 3016                2238.0  English    6000000.0      1972.0         9.2
# 2543                 650.0  English   13000000.0      1974.0         9.0
# 64                  4667.0  English  185000000.0      2008.0         9.0
# 325                 3189.0  English   94000000.0      2003.0         8.9
#
#       movie_facebook_likes  net profit  Rank
# 1795                108000    3.341469     1
# 3016                 43000  128.821952     2
# 2543                 14000   44.300000     3
# 64                   37000  348.316061     4
# 325                  16000  283.019252     5

# %%
IMDb_Top_250[(IMDb_Top_250['imdb_score']>=7.5)&(IMDb_Top_250['imdb_score']<8)].shape
# Out:
# (34, 15)

# %%
IMDb_Top_250[(IMDb_Top_250['imdb_score']>=7.5)&(IMDb_Top_250['imdb_score']<8)].shape
# Out:
# (34, 15)

# %%
rows, cols = IMDb_Top_250[(IMDb_Top_250['imdb_score']>=8)&(IMDb_Top_250['imdb_score']<8.5)].shape
rows, cols # this row is highest
# Out:
# (159, 15)

# %%
IMDb_Top_250[(IMDb_Top_250['imdb_score']>=8.5)&(IMDb_Top_250['imdb_score']<9)].shape
# Out:
# (42, 15)

# %%
IMDb_Top_250[(IMDb_Top_250['imdb_score']>=9)&(IMDb_Top_250['imdb_score']<9.5)].shape
# Out:
# (4, 15)

# %%
IMDb_Top_250[(IMDb_Top_250['imdb_score']>=9.5)&(IMDb_Top_250['imdb_score']<10)].shape
# Out:
# (0, 15)

# %% [markdown]
# #### <font color='white'>Question 7: Suppose movies are divided into 5 buckets based on the IMDb ratings: </font>
#
# -  <font color='red'>7.5 to 8</font>
# -  <font color='green'>8 to 8.5</font>
# -  <font color='red'>8.5 to 9</font>
# -  <font color='red'>9 to 9.5</font>
# -  <font color='red'>9.5 to 10</font>
#
# <font color = 'green'> Which bucket holds the maximum number of movies from *IMDb_Top_250*? </font>

# %%
import matplotlib.pyplot as plt

plt.hist(IMDb_Top_250['imdb_score'], bins = 5, range = (7.5,10), edgecolor = 'cyan')
plt.show()

# Ans.
# [8, 8.5)

# %% [markdown]
# **Subtask 3.4: Find the critic-favorite and audience-favorite actors**
#
#    1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#    2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#    3. Group the combined dataframe using the `actor_1_name` column.
#    4. Find the mean of the `num_critic_for_reviews` and `num_user_for_review` and identify the actors which have the highest mean.

# %%
# Write your code for creating three new dataframes here
Meryl_Streep = new_movies[new_movies['actor_1_name'] == 'Meryl Streep']
Meryl_Streep.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 392     Nancy Meyers                   187.0  112703470.0
# 1038   Curtis Hanson                    42.0   46815748.0
# 1132     Nora Ephron                   252.0   94125426.0
# 1322   David Frankel                   208.0  124732962.0
# 1390  Robert Redford                   227.0   14998070.0
#
#                                genres  actor_1_name             movie_title  \
# 392              Comedy|Drama|Romance  Meryl Streep       It's Complicated
# 1038  Action|Adventure|Crime|Thriller  Meryl Streep         The River Wild
# 1132          Biography|Drama|Romance  Meryl Streep          Julie & Julia
# 1322             Comedy|Drama|Romance  Meryl Streep  The Devil Wears Prada
# 1390               Drama|Thriller|War  Meryl Streep        Lions for Lambs
#
#       num_voted_users  num_user_for_reviews language      budget  title_year  \
# 392             69860                 214.0  English  85000000.0      2009.0
# 1038            32544                  69.0  English  45000000.0      1994.0
# 1132            79264                 277.0  English  40000000.0      2009.0
# 1322           286178                 631.0  English  35000000.0      2006.0
# 1390            41170                 298.0  English  35000000.0      2007.0
#
#       imdb_score  movie_facebook_likes  net profit
# 392          6.6                     0   27.703470
# 1038         6.3                     0    1.815748
# 1132         7.0                 13000   54.125426
# 1322         6.8                     0   89.732962
# 1390         6.2                     0  -20.001930

# %%
Leo_Caprio = new_movies[new_movies['actor_1_name'] == 'Leonardo DiCaprio']
Leo_Caprio.head()
# Out:
#              director_name  num_critic_for_reviews        gross  \
# 25           James Cameron                   315.0  658672302.0
# 49            Baz Luhrmann                   490.0  144812796.0
# 94       Christopher Nolan                   642.0  292568851.0
# 173  Alejandro G. Iñárritu                   556.0  183635922.0
# 246        Martin Scorsese                   267.0  102608827.0
#
#                                genres       actor_1_name        movie_title  \
# 25                      Drama|Romance  Leonardo DiCaprio           Titanic
# 49                      Drama|Romance  Leonardo DiCaprio  The Great Gatsby
# 94   Action|Adventure|Sci-Fi|Thriller  Leonardo DiCaprio         Inception
# 173  Adventure|Drama|Thriller|Western  Leonardo DiCaprio      The Revenant
# 246                   Biography|Drama  Leonardo DiCaprio       The Aviator
#
#      num_voted_users  num_user_for_reviews language       budget  title_year  \
# 25            793059                2528.0  English  200000000.0      1997.0
# 49            362912                 753.0  English  105000000.0      2013.0
# 94           1468200                2803.0  English  160000000.0      2010.0
# 173           406020                1188.0  English  135000000.0      2015.0
# 246           264318                 799.0  English  110000000.0      2004.0
#
#      imdb_score  movie_facebook_likes  net profit
# 25          7.7                 26000  458.672302
# 49          7.3                115000   39.812796
# 94          8.8                175000  132.568851
# 173         8.1                190000   48.635922
# 246         7.5                     0   -7.391173

# %%
Brad_Pitt = new_movies[new_movies['actor_1_name'] == 'Brad Pitt']
Brad_Pitt.head()
# Out:
#          director_name  num_critic_for_reviews        gross  \
# 97       David Fincher                   362.0  127490802.0
# 142  Wolfgang Petersen                   220.0  133228348.0
# 243  Steven Soderbergh                   198.0  125531634.0
# 244         Doug Liman                   233.0  186336103.0
# 367         Tony Scott                   142.0      26871.0
#
#                                    genres actor_1_name  \
# 97                  Drama|Fantasy|Romance    Brad Pitt
# 142                             Adventure    Brad Pitt
# 243                        Crime|Thriller    Brad Pitt
# 244  Action|Comedy|Crime|Romance|Thriller    Brad Pitt
# 367                 Action|Crime|Thriller    Brad Pitt
#
#                               movie_title  num_voted_users  \
# 97   The Curious Case of Benjamin Button            459346
# 142                                 Troy            381672
# 243                       Ocean's Twelve            284852
# 244                     Mr. & Mrs. Smith            348861
# 367                             Spy Game            121259
#
#      num_user_for_reviews language       budget  title_year  imdb_score  \
# 97                  822.0  English  150000000.0      2008.0         7.8
# 142                1694.0  English  175000000.0      2004.0         7.2
# 243                 627.0  English  110000000.0      2004.0         6.4
# 244                 798.0  English  120000000.0      2005.0         6.5
# 367                 361.0  English   92000000.0      2001.0         7.0
#
#      movie_facebook_likes  net profit
# 97                  23000  -22.509198
# 142                     0  -41.771652
# 243                     0   15.531634
# 244                     0   66.336103
# 367                     0  -91.973129

# %%
# Write your code for combining the three dataframes here
Combined = pd.concat([Meryl_Streep, Leo_Caprio, Brad_Pitt], axis = 0)

# print(Combined.shape)
Combined.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 392     Nancy Meyers                   187.0  112703470.0
# 1038   Curtis Hanson                    42.0   46815748.0
# 1132     Nora Ephron                   252.0   94125426.0
# 1322   David Frankel                   208.0  124732962.0
# 1390  Robert Redford                   227.0   14998070.0
#
#                                genres  actor_1_name             movie_title  \
# 392              Comedy|Drama|Romance  Meryl Streep       It's Complicated
# 1038  Action|Adventure|Crime|Thriller  Meryl Streep         The River Wild
# 1132          Biography|Drama|Romance  Meryl Streep          Julie & Julia
# 1322             Comedy|Drama|Romance  Meryl Streep  The Devil Wears Prada
# 1390               Drama|Thriller|War  Meryl Streep        Lions for Lambs
#
#       num_voted_users  num_user_for_reviews language      budget  title_year  \
# 392             69860                 214.0  English  85000000.0      2009.0
# 1038            32544                  69.0  English  45000000.0      1994.0
# 1132            79264                 277.0  English  40000000.0      2009.0
# 1322           286178                 631.0  English  35000000.0      2006.0
# 1390            41170                 298.0  English  35000000.0      2007.0
#
#       imdb_score  movie_facebook_likes  net profit
# 392          6.6                     0   27.703470
# 1038         6.3                     0    1.815748
# 1132         7.0                 13000   54.125426
# 1322         6.8                     0   89.732962
# 1390         6.2                     0  -20.001930

# %%
# Write your code for grouping the combined dataframe here
combined = Combined.groupby(by = 'actor_1_name')
combined.sum(numeric_only=True)
# Out:
#                    num_critic_for_reviews         gross  num_voted_users  \
# actor_1_name
# Brad Pitt                          4165.0  1.127465e+09          4820925
# Leonardo DiCaprio                  6934.0  2.640582e+09          9281136
# Meryl Streep                       1996.0  6.591170e+08           809001
#
#                    num_user_for_reviews        budget  title_year  imdb_score  \
# actor_1_name
# Brad Pitt                       12620.0  1.178000e+09     34074.0       121.6
# Leonardo DiCaprio               19204.0  1.731500e+09     42115.0       157.4
# Meryl Streep                     3269.0  3.790000e+08     22039.0        74.2
#
#                    movie_facebook_likes  net profit
# actor_1_name
# Brad Pitt                        238880  -50.535372
# Leonardo DiCaprio               1096000  909.081774
# Meryl Streep                      32275  280.117002

# %%
# Write the code for finding the mean of critic reviews and audience reviews here
high_rated = combined.mean(numeric_only=True)[['num_user_for_reviews', 'num_critic_for_reviews']]
high_rated
# Out:
#                    num_user_for_reviews  num_critic_for_reviews
# actor_1_name
# Brad Pitt                    742.352941              245.000000
# Leonardo DiCaprio            914.476190              330.190476
# Meryl Streep                 297.181818              181.454545

# %%
actor_name = high_rated.loc[high_rated['num_user_for_reviews'] == high_rated['num_user_for_reviews'].max()]
actor_name
# Out:
#                    num_user_for_reviews  num_critic_for_reviews
# actor_1_name
# Leonardo DiCaprio             914.47619              330.190476

# %% [markdown]
# #### <font color='white'>Question 8: Which actor is highest rated among the three actors according to the user reviews? </font>
#
# -  <font color='red'>Meryl Streep</font>
# -  <font color='green'>Leonardo DiCaprio</font>
# -  <font color='red'>Brad Pitt</font>

# %%
actor_name.index[0]
# Out:
# 'Leonardo DiCaprio'

# %% [markdown]
# #### <font color='white'>Question 9: Which actor is highest rated among the three actors according to the critics?</font>
#
# -  <font color='red'>Meryl Streep</font>
# -  <font color='green'>Leonardo DiCaprio</font>
# -  <font color='red'>Brad Pitt</font>

# %%
high_rated.loc[high_rated['num_critic_for_reviews'] == high_rated['num_critic_for_reviews'].max()].index[0]
# Out:
# 'Leonardo DiCaprio'

# %% [markdown]
# # [pandas.concat() function in Python](https://www.geeksforgeeks.org/pandas-concat-function-in-python/)

# %%
# importing the module
import pandas as pd
 
# creating the DataFrames
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3']})
display('df1:', df1)
df2 = pd.DataFrame({'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']})
display('df2:', df2)
 
# concatenating : Axis 0 is default
display('After concatenating: Axis = 1')
display(pd.concat([df1, df2],
                  axis = 1, 
                  keys = ['key1', 'key2'],
                  ))

display('After concatenating: Axis = 0')
display(pd.concat([df1, df2],
                  axis = 0, 
                  keys = ['key1', 'key2'],
                  ))
# Out:
# 'df1:'
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 'df2:'
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3
# 'After concatenating: Axis = 1'
#   key1     key2
#      A   B    C   D
# 0   A0  B0   C0  D0
# 1   A1  B1   C1  D1
# 2   A2  B2   C2  D2
# 3   A3  B3   C3  D3
# 'After concatenating: Axis = 0'
#           A    B    C    D
# key1 0   A0   B0  NaN  NaN
#      1   A1   B1  NaN  NaN
#      2   A2   B2  NaN  NaN
#      3   A3   B3  NaN  NaN
# key2 0  NaN  NaN   C0   D0
#      1  NaN  NaN   C1   D1
#      2  NaN  NaN   C2   D2
#      3  NaN  NaN   C3   D3
